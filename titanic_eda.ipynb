# %%
import pandas as pd 
from matplotlib import pyplot as plt
df = pd.read_csv(r"C:\Users\sjvar\Downloads\titanic\test.csv")
df.fillna("Unknown")
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex      Age  SibSp  Parch              Ticket     Fare    Cabin  \
# ...

# %%
df.fillna({
    'Age': "Age Unknown",
    'Cabin' : "Cabin Unknown",
})
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex          Age  SibSp  Parch              Ticket      Fare  \
# ...

# %%
df.fillna(method = "bfill",axis = 1, limit = 1)
# Out:
# C:\Users\sjvar\AppData\Local\Temp\ipykernel_32548\1195055680.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "bfill",axis = 1, limit = 1)
#     PassengerId Pclass                                          Name     Sex  \
# 0           892      3                              Kelly, Mr. James    male
# 1           893      3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           894      2                     Myles, Mr. Thomas Francis    male
# 3           895      3                              Wirz, Mr. Albert    male
# 4           896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..          ...    ...                                           ...     ...
# 413        1305      3                            Spector, Mr. Woolf    male
# 414        1306      1                  Oliva y Ocana, Dona. Fermina  female
# ...

# %%
df.fillna(method = "bfill",axis = 0, limit = 1)
# Out:
# C:\Users\sjvar\AppData\Local\Temp\ipykernel_32548\151917360.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "bfill",axis = 0, limit = 1)
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# ...

# %%
df.interpolate()
# Out:
# C:\Users\sjvar\AppData\Local\Temp\ipykernel_32548\4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# ...

# %%
a = pd.DataFrame({
    'students':["Raju","Umesh","Nazeer"],
    'Maths':[10,20,30],
    'Science':[60,80,58]
})
a
# Out:
#   students  Maths  Science
# 0     Raju     10       60
# 1    Umesh     20       80
# 2   Nazeer     30       58

# %%
a.reindex([0,1,22,2])
# Out:
#    students  Maths  Science
# 0      Raju   10.0     60.0
# 1     Umesh   20.0     80.0
# 22      NaN    NaN      NaN
# 2    Nazeer   30.0     58.0

# %%
idx=['s1','s2','s3']
a.set_index('students')
# Out:
#           Maths  Science
# students
# Raju         10       60
# Umesh        20       80
# Nazeer       30       58

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.loc[0:2]
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
print(df.loc[0,'PassengerId'])
# Out:
# 892

# %%
print(df.loc[0:2,'Name'])
# Out:
# 0                    Kelly, Mr. James
# 1    Wilkes, Mrs. James (Ellen Needs)
# 2           Myles, Mr. Thomas Francis
# Name: Name, dtype: object

# %%
df.loc[0:3]
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
# 3          895       3                  Wirz, Mr. Albert    male  27.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q
# 3      0  315154  8.6625   NaN        S

# %%
df.loc[0:10,['Name','Sex']]
# Out:
#                                             Name     Sex
# 0                               Kelly, Mr. James    male
# 1               Wilkes, Mrs. James (Ellen Needs)  female
# 2                      Myles, Mr. Thomas Francis    male
# 3                               Wirz, Mr. Albert    male
# 4   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5                     Svensson, Mr. Johan Cervin    male
# 6                           Connolly, Miss. Kate  female
# 7                   Caldwell, Mr. Albert Francis    male
# 8      Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9                        Davies, Mr. John Samuel    male
# 10                              Ilieff, Mr. Ylio    male

# %%
df.iloc[0:4,1]
# Out:
# 0    3
# 1    3
# 2    2
# 3    3
# Name: Pclass, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
df.groupby(['Pclass'])['Fare'].sum()
# Out:
# Pclass
# 1    10087.9918
# 2     2064.7957
# 3     2703.7501
# Name: Fare, dtype: float64

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.groupby(['Pclass','Sex']).count()
# Out:
#                PassengerId  Name  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# Pclass Sex
# 1      female           50    50   48     50     50      50    50     40
#        male             57    57   50     57     57      57    57     40
# 2      female           30    30   29     30     30      30    30      3
#        male             63    63   59     63     63      63    63      4
# 3      female           72    72   50     72     72      72    72      1
#        male            146   146   96    146    146     146   145      3
#
#                Embarked
# Pclass Sex
# 1      female        50
#        male          57
# 2      female        30
#        male          63
# 3      female        72
#        male         146

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.groupby(['Pclass']).agg({
    'Age':['mean','sum'],
    'Fare':'mean'
})
# Out:
#               Age                Fare
#              mean      sum       mean
# Pclass
# 1       40.918367  4010.00  94.280297
# 2       28.777500  2532.42  22.202104
# 3       24.027945  3508.08  12.459678

# %%
for x,y in df.groupby(['Sex','Pclass'])['Fare']:
    print(f"Team:{x}")
    print(y)
# Out:
# Team:('female', np.int64(1))
# 12      82.2667
# 14      61.1750
# 22      31.6833
# 24     262.3750
# 26      61.9792
# 44      52.5542
# 48      76.2917
# 53     263.0000
# 59     262.3750
# 69     263.0000
# 74     211.5000
# 77      25.7000
# 92      52.0000
# 96      78.8500
# 100     55.4417
# 112     31.6792
# 114    221.7792
# 122     57.7500
# 141    151.5500
# 150     83.1583
# 156    221.7792
# 168     27.7208
# 179     83.1583
# 182     53.1000
# 184    247.5208
# 208     27.7208
# 218    211.5000
# 224     27.4458
# 231     26.5500
# 239    106.4250
# 240     27.7208
# 272    136.7792
# 305     26.5500
# 314    135.6333
# 324    211.3375
# 343    512.3292
# 350     63.3583
# 356     51.4792
# 364     55.4417
# 368     59.4000
# 371    134.5000
# 374     81.8583
# 375    262.3750
# 391     39.4000
# 395     60.0000
# 397     79.2000
# 400    164.8667
# 402     59.4000
# 411     90.0000
# 414    108.9000
# Name: Fare, dtype: float64
# Team:('female', np.int64(2))
# ...

# %%
df.groupby('Pclass', as_index=False)['Fare'].mean()
# Out:
# Pclass
# 1    94.280297
# 2    22.202104
# 3    12.459678
# Name: Fare, dtype: float64

# %%
df_meanfare = df.groupby('Pclass')['Fare'].transform('mean')
df_meanfare
# Out:
# 0      12.459678
# 1      12.459678
# 2      22.202104
# 3      12.459678
# 4      12.459678
#          ...
# 413    12.459678
# 414    94.280297
# 415    12.459678
# 416    12.459678
# 417    12.459678
# Name: Fare, Length: 418, dtype: float64

# %%
df.groupby('Pclass')['Fare'].mean().plot(kind='bar',color='m',alpha=0.4)
# Out:
# <Axes: xlabel='Pclass'>

# %%
df.sort_values('Fare',ascending = False,na_position = 'first',axis = 0
              )
# Out:
#      PassengerId  Pclass                                               Name  \
# 152         1044       3                                 Storey, Mr. Thomas
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 53           945       1                         Fortune, Miss. Ethel Flora
# 59           951       1                        Chaudanson, Miss. Victorine
# ..           ...     ...                                                ...
# 116         1008       3                                   Thomas, Mr. John
# 133         1025       3                              Thomas, Mr. Charles P
# 21           913       3                          Olsen, Master. Artur Karl
# 266         1158       1              Chisholm, Mr. Roderick Robert Crispin
# 372         1264       1                            Ismay, Mr. Joseph Bruce
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %% [markdown]
# ### Sorting a data frame first by pclass ascending and then by age descending

# %%
df.sort_values(by=['Pclass','Age'], ascending = [True,False])
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %% [markdown]
# ## sort the dataframe by age but place all missing (nan) age values at the beginning

# %%
df.sort_values('Age',na_position='first')
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 81           973       1                                 Straus, Mr. Isidor
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
# ...

# %% [markdown]
# ### sort the dataframe by sex ignoring uppercase and lowercase differences

# %%
df.sort_values("Sex",key=(lambda x : x.str.lower()))
# Out:
#      PassengerId  Pclass                                               Name  \
# 208         1100       1                      Rosenbaum, Miss. Edith Louise
# 138         1030       3                              Drapkin, Miss. Jennie
# 330         1222       2  Davies, Mrs. John Morgan (Elizabeth Agnes Mary...
# 140         1032       3                        Goodwin, Miss. Jessie Allis
# 141         1033       1                               Daniels, Miss. Sarah
# ..           ...     ...                                                ...
# 167         1059       3                            Ford, Mr. Edward Watson
# 166         1058       1                                 Brandeis, Mr. Emil
# 164         1056       2                      Peruschitz, Rev. Joseph Maria
# 131         1023       1                          Gracie, Col. Archibald IV
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df.sort_values('Name',key = lambda col:col.str.lower())
# Out:
#      PassengerId  Pclass                                       Name     Sex  \
# 392         1284       3              Abbott, Master. Eugene Joseph    male
# 345         1237       3                Abelseth, Miss. Karen Marie  female
# 57           949       3              Abelseth, Mr. Olaus Jorgensen    male
# 251         1143       3   Abrahamsson, Mr. Abraham August Johannes    male
# 8            900       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# ..           ...     ...                                        ...     ...
# 3            895       3                           Wirz, Mr. Albert    male
# 294         1186       3                  Wittevrongel, Mr. Camille    male
# 162         1054       2                       Wright, Miss. Marion  female
# 136         1028       3                  Zakarian, Mr. Mapriededer    male
# 171         1063       3                        Zakarian, Mr. Ortin    male
#
# ...

# %% [markdown]
# ## sort the columns of the dataframe based on the values in the first row

# %%
# df.sort_values(by = 0 ,axis = 1)

# %% [markdown]
# # value_counts()

# %%
df.Pclass.value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
df.Embarked.value_counts(normalize = True)
# Out:
# Embarked
# S    0.645933
# C    0.244019
# Q    0.110048
# Name: proportion, dtype: float64

# %%
df.Age.value_counts(ascending=False)
# Out:
# Age
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 44.0     1
# 5.0      1
# 51.0     1
# 3.0      1
# 38.5     1
# Name: count, Length: 79, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
df.Cabin.value_counts(dropna = False)
# Out:
# Cabin
# NaN                327
# B57 B59 B63 B66      3
# B45                  2
# C23 C25 C27          2
# C78                  2
#                   ...
# B41                  1
# C7                   1
# D40                  1
# D38                  1
# C105                 1
# Name: count, Length: 77, dtype: int64

# %%
df.Fare.value_counts(bins = 5)
# Out:
# (-0.513, 102.466]     386
# (204.932, 307.398]     17
# (102.466, 204.932]     13
# (409.863, 512.329]      1
# (307.398, 409.863]      0
# Name: count, dtype: int64

# %%
df.groupby('Pclass')['Sex'].value_counts()
# Out:
# Pclass  Sex
# 1       male       57
#         female     50
# 2       male       63
#         female     30
# 3       male      146
#         female     72
# Name: count, dtype: int64

# %%
# converting the series into a dataframe
a=df['Name'].value_counts().reset_index()
a.index
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a = df['Name'].value_counts()
# a.index
type(a)
# Out:
# pandas.core.series.Series

# %%
df.apply(lambda x : x.value_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[199], line 1
# ----> 1 df.apply(lambda x : x.value_counts())
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)  10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# ...

# %%
result = {col: df[col].value_counts() for col in df.columns}
result
# Out:
# {'PassengerId': PassengerId
#  1309    1
#  892     1
#  1293    1
#  1292    1
#  1291    1
#         ..
#  898     1
#  897     1
#  896     1
#  895     1
#  894     1
#  Name: count, Length: 418, dtype: int64,
#  'Pclass': Pclass
#  3    218
#  1    107
#  2     93
#  Name: count, dtype: int64,
#  'Name': Name
#  Peter, Master. Michael J                        1
#  Kelly, Mr. James                                1
#  Gale, Mr. Harry                                 1
#  Bonnell, Miss. Caroline                         1
#  Conlon, Mr. Thomas Henry                        1
#                                                 ..
#  Connolly, Miss. Kate                            1
#  Svensson, Mr. Johan Cervin                      1
#  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
#  Wirz, Mr. Albert                                1
#  Myles, Mr. Thomas Francis                       1
#  Name: count, Length: 418, dtype: int64,
#  'Sex': Sex
#  male      266
#  female    152
# ...
